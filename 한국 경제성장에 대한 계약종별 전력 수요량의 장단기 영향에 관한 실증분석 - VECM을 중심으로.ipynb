# %%
import pandas as pd
import numpy as np
from statsmodels.tsa.stattools import adfuller
from statsmodels.tsa.stattools import coint
from statsmodels.tsa.vector_ar.vecm import *

# %%
df = pd.read_csv("C:/Users/rldhks/Desktop/데이터 사이언스/2학기/목-고급통계/기말 프로젝트 데이터/GDP ELEC여러개.csv")

# %%
df
# Out:
#        DATE         주택용          일반용          교육용          산업용           농사용  \
# 0   20021/4  3643320341   4534223992  221568437.7  12068371428  5.193177e+08
# 1   20022/4  3422247274   4425665046  242530285.3  12653121706  4.669948e+08
# 2   20023/4  3702819273   5443779035  245737116.3  12638504125  5.230518e+08
# 3   20024/4  3714222859   4736278476  274677921.7  13038069625  5.963270e+08
# 4   20031/4  3999313919   5079815451  267104374.7  12910219231  5.441708e+08
# ..      ...         ...          ...          ...          ...           ...
# 77  20212/4  5954884937   8734089195  581196390.7  23928929774  1.433831e+09
# 78  20213/4  7791035973  10966843616  658140299.7  24762203275  1.780450e+09
# 79  20214/4  6227200425   9737713738  724080678.0  24459560230  1.734758e+09
# 80  20221/4  6792167185  11138841986  904761209.3  24992283460  2.070610e+09
# 81  20222/4  6019683068   9456374271  635161953.3  24400611232  1.556831e+09
#
#             가로등            심야     GDP
# ...

# %%
from matplotlib import font_manager, rc
import platform

# 이미지에 한글 표시 설정
if platform.system() == 'Windows': # 윈도우인 경우 맑은고딕
    font_name = font_manager.FontProperties(fname="c:/Windows/Fonts/malgun.ttf").get_name()
    rc('font', family=font_name)
else :  # Mac인 경우 애플고딕
    rc('font', family='AppleGothic')
matplotlib.rcParams['axes.unicode_minus'] = False

# %%
import matplotlib.pyplot as plt

plt.figure(1)
plt.title('주택용')
plt.xlabel('TIME')
plt.ylabel('VALUE')
plt.grid(axis='y')
plt.xticks(list(range(0,82)))
plt.plot(list(range(0,82)), np.log(df['주택용']))
plt.legend(['주택용'])
plt.show()

plt.figure(1)
plt.title('일반용')
plt.xlabel('TIME')
plt.ylabel('VALUE')
plt.grid(axis='y')
plt.xticks(list(range(0,82)))
plt.plot(list(range(0,82)), np.log(df['일반용']))
plt.legend(['일반용'])
plt.show()

plt.figure(1)
plt.title('교육용')
plt.xlabel('TIME')
plt.ylabel('VALUE')
plt.grid(axis='y')
plt.xticks(list(range(0,82)))
plt.plot(list(range(0,82)), np.log(df['교육용']))
plt.legend(['교육용'])
plt.show()

plt.figure(1)
plt.title('산업용')
plt.xlabel('TIME')
plt.ylabel('VALUE')
plt.grid(axis='y')
plt.xticks(list(range(0,82)))
plt.plot(list(range(0,82)), np.log(df['산업용']))
plt.legend(['산업용'])
plt.show()

plt.figure(1)
plt.title('농사용')
plt.xlabel('TIME')
plt.ylabel('VALUE')
plt.grid(axis='y')
plt.xticks(list(range(0,82)))
plt.plot(list(range(0,82)), np.log(df['농사용']))
plt.legend(['농사용'])
plt.show()

plt.figure(1)
plt.title('가로등')
plt.xlabel('TIME')
plt.ylabel('VALUE')
plt.grid(axis='y')
plt.xticks(list(range(0,82)))
plt.plot(list(range(0,82)), np.log(df['가로등']))
plt.legend(['가로등'])
plt.show()

plt.figure(1)
plt.title('심야')
plt.xlabel('TIME')
plt.ylabel('VALUE')
plt.grid(axis='y')
plt.xticks(list(range(0,82)))
plt.plot(list(range(0,82)), np.log(df['심야']))
plt.legend(['심야'])
plt.show()

plt.figure(2)
plt.title('GDP')
plt.xlabel('TIME')
plt.ylabel('VALUE')
plt.grid(axis='y')
plt.xticks(list(range(0,82)))
plt.plot(list(range(0,82)), np.log(df['GDP']))
plt.legend([ 'GDP'])
plt.show()

# %%
df['주택용'] = np.log(df['주택용'])
df['일반용'] = np.log(df['일반용'])
df['교육용'] = np.log(df['교육용'])
df['산업용'] = np.log(df['산업용'])
df['농사용'] = np.log(df['농사용'])
df['가로등'] = np.log(df['가로등'])
df['심야'] = np.log(df['심야'])
df['GDP'] = np.log(df['GDP'])

# %%
for i in df.columns[1:]:
    result = adfuller(df[i])
    
    print(f'*******{i}*******')
    print('ADF Statistic: %f' % result[0])
    print('p-value: %f' % result[1])
    print('Critical Values:')
    for key, value in result[4].items():
        print('\t%s: %.3f' % (key, value))
    print("")
# Out:
# *******주택용*******
# ADF Statistic: -1.507740
# p-value: 0.529679
# Critical Values:
# 	1%: -3.523
# 	5%: -2.902
# 	10%: -2.588
#
# *******일반용*******
# ADF Statistic: -1.920478
# p-value: 0.322490
# Critical Values:
# 	1%: -3.523
# 	5%: -2.902
# 	10%: -2.588
#
# *******교육용*******
# ADF Statistic: -2.806845
# p-value: 0.057303
# Critical Values:
# 	1%: -3.526
# 	5%: -2.903
# 	10%: -2.589
#
# *******산업용*******
# ADF Statistic: -2.451333
# p-value: 0.127769
# Critical Values:
# 	1%: -3.515
# 	5%: -2.898
# 	10%: -2.586
#
# *******농사용*******
# ADF Statistic: -2.491544
# p-value: 0.117545
# Critical Values:
# 	1%: -3.522
# 	5%: -2.901
# 	10%: -2.588
#
# *******가로등*******
# ADF Statistic: -1.719729
# p-value: 0.420977
# Critical Values:
# 	1%: -3.529
# 	5%: -2.904
# 	10%: -2.590
#
# *******심야*******
# ADF Statistic: -0.248375
# p-value: 0.932504
# Critical Values:
# 	1%: -3.529
# 	5%: -2.904
# 	10%: -2.590
#
# *******GDP*******
# ADF Statistic: -2.782034
# p-value: 0.060886
# ...

# %% [markdown]
# # 차분

# %%
for i in df.columns[1:]:
    df['1차 차분_'+str(i)] = df[i].diff()

# %%
df.loc[:]
# Out:
#        DATE        주택용        일반용        교육용        산업용        농사용        가로등  \
# 0   20021/4  22.016161  22.234920  19.216242  23.213854  20.068026  19.021638
# 1   20022/4  21.953563  22.210686  19.306637  23.261170  19.961829  18.866220
# 2   20023/4  22.032360  22.417739  19.319773  23.260014  20.075191  18.870667
# 3   20024/4  22.035435  22.278518  19.431110  23.291139  20.206300  19.091678
# 4   20031/4  22.109389  22.348541  19.403150  23.281285  20.114774  19.110695
# ..      ...        ...        ...        ...        ...        ...        ...
# 77  20212/4  22.507478  22.890500  20.180599  23.898354  21.083615  19.407522
# 78  20213/4  22.776240  23.118142  20.304929  23.932584  21.300132  19.387083
# 79  20214/4  22.552193  22.999272  20.400413  23.920287  21.274134  19.541409
# 80  20221/4  22.639036  23.133704  20.623182  23.941833  21.451109  19.547382
# 81  20222/4  22.518300  22.969955  20.269391  23.917874  21.165918  19.402744
#
# ...

# %%
for i in df.columns[10:]:
    result = adfuller(df[i].loc[1:])
    
    print(f'*******{i}*******')
    print('ADF Statistic: %f' % result[0])
    print('p-value: %f' % result[1])
    print('Critical Values:')
    for key, value in result[4].items():
        print('\t%s: %.3f' % (key, value))
    print("")
# Out:
# *******1차 차분_일반용*******
# ADF Statistic: -2.146266
# p-value: 0.226322
# Critical Values:
# 	1%: -3.523
# 	5%: -2.902
# 	10%: -2.588
#
# *******1차 차분_교육용*******
# ADF Statistic: -1.986889
# p-value: 0.292351
# Critical Values:
# 	1%: -3.525
# 	5%: -2.903
# 	10%: -2.589
#
# *******1차 차분_산업용*******
# ADF Statistic: -11.572627
# p-value: 0.000000
# Critical Values:
# 	1%: -3.515
# 	5%: -2.898
# 	10%: -2.586
#
# *******1차 차분_농사용*******
# ADF Statistic: -6.272724
# p-value: 0.000000
# Critical Values:
# 	1%: -3.522
# 	5%: -2.901
# 	10%: -2.588
#
# *******1차 차분_가로등*******
# ADF Statistic: -2.076660
# p-value: 0.254003
# Critical Values:
# 	1%: -3.530
# 	5%: -2.905
# 	10%: -2.590
#
# *******1차 차분_심야*******
# ADF Statistic: -1.489648
# p-value: 0.538626
# Critical Values:
# 	1%: -3.529
# 	5%: -2.904
# 	10%: -2.590
#
# *******1차 차분_GDP*******
# ADF Statistic: -2.668212
# p-value: 0.079702
# Critical Values:
# 	1%: -3.523
# 	5%: -2.902
# 	10%: -2.588

# %%
for i in df.columns[1:9]:
    df['2차 차분_'+str(i)] = df[i].diff().diff()

# %%
df
# Out:
#        DATE        주택용        일반용        교육용        산업용        농사용        가로등  \
# 0   20021/4  22.016161  22.234920  19.216242  23.213854  20.068026  19.021638
# 1   20022/4  21.953563  22.210686  19.306637  23.261170  19.961829  18.866220
# 2   20023/4  22.032360  22.417739  19.319773  23.260014  20.075191  18.870667
# 3   20024/4  22.035435  22.278518  19.431110  23.291139  20.206300  19.091678
# 4   20031/4  22.109389  22.348541  19.403150  23.281285  20.114774  19.110695
# ..      ...        ...        ...        ...        ...        ...        ...
# 77  20212/4  22.507478  22.890500  20.180599  23.898354  21.083615  19.407522
# 78  20213/4  22.776240  23.118142  20.304929  23.932584  21.300132  19.387083
# 79  20214/4  22.552193  22.999272  20.400413  23.920287  21.274134  19.541409
# 80  20221/4  22.639036  23.133704  20.623182  23.941833  21.451109  19.547382
# 81  20222/4  22.518300  22.969955  20.269391  23.917874  21.165918  19.402744
#
# ...

# %%
for i in df.columns[17:]:
    print(i)
# Out:
# 2차 차분_주택용
# 2차 차분_일반용
# 2차 차분_교육용
# 2차 차분_산업용
# 2차 차분_농사용
# 2차 차분_가로등
# 2차 차분_심야
# 2차 차분_GDP

# %%
for i in df.columns[17:]:
    result = adfuller(df[i].loc[2:])
    
    print(f'*******{i}*******')
    print('ADF Statistic: %f' % result[0])
    print('p-value: %f' % result[1])
    print('Critical Values:')
    for key, value in result[4].items():
        print('\t%s: %.3f' % (key, value))
    print("")
# Out:
# *******2차 차분_주택용*******
# ADF Statistic: -5.132872
# p-value: 0.000012
# Critical Values:
# 	1%: -3.529
# 	5%: -2.904
# 	10%: -2.590
#
# *******2차 차분_일반용*******
# ADF Statistic: -7.411007
# p-value: 0.000000
# Critical Values:
# 	1%: -3.523
# 	5%: -2.902
# 	10%: -2.588
#
# *******2차 차분_교육용*******
# ADF Statistic: -4.972236
# p-value: 0.000025
# Critical Values:
# 	1%: -3.525
# 	5%: -2.903
# 	10%: -2.589
#
# *******2차 차분_산업용*******
# ADF Statistic: -5.387461
# p-value: 0.000004
# Critical Values:
# 	1%: -3.523
# 	5%: -2.902
# 	10%: -2.588
#
# *******2차 차분_농사용*******
# ADF Statistic: -5.869319
# p-value: 0.000000
# Critical Values:
# 	1%: -3.529
# 	5%: -2.904
# 	10%: -2.590
#
# *******2차 차분_가로등*******
# ADF Statistic: -3.580808
# p-value: 0.006139
# Critical Values:
# 	1%: -3.530
# 	5%: -2.905
# 	10%: -2.590
#
# *******2차 차분_심야*******
# ADF Statistic: -4.367730
# p-value: 0.000338
# Critical Values:
# 	1%: -3.530
# 	5%: -2.905
# 	10%: -2.590
#
# *******2차 차분_GDP*******
# ...

# %%
data = df[['2차 차분_주택용', '2차 차분_일반용', '2차 차분_교육용',
           '1차 차분_산업용', '1차 차분_농사용', '2차 차분_가로등', 
           '2차 차분_심야', '2차 차분_GDP']].iloc[2:].reset_index()
data = data.drop(columns='index')

# %%
data
# Out:
#     2차 차분_주택용  2차 차분_일반용  2차 차분_교육용  1차 차분_산업용  1차 차분_농사용  2차 차분_가로등  \
# 0    0.141395   0.231286  -0.077259  -0.001156   0.113362   0.159865
# 1   -0.075722  -0.346275   0.098201   0.031125   0.131109   0.216564
# 2    0.070878   0.209245  -0.139297  -0.009854  -0.091526  -0.201993
# 3   -0.151208  -0.135949   0.060130   0.018920  -0.167365  -0.225882
# 4    0.130036   0.244559  -0.046480  -0.019996   0.080476   0.217007
# ..        ...        ...        ...        ...        ...        ...
# 75  -0.209337  -0.335297  -0.627796  -0.001316  -0.291297  -0.138491
# 76   0.381442   0.403318   0.497532   0.034230   0.216517   0.125131
# 77  -0.492809  -0.346513  -0.028845  -0.012297  -0.025998   0.174765
# 78   0.310890   0.253302   0.127284   0.021546   0.176975  -0.148353
# 79  -0.207579  -0.298181  -0.576559  -0.023959  -0.285191  -0.150611
#
#     2차 차분_심야  2차 차분_GDP
# 0  -0.292323  -0.053086
# 1   2.193759   0.048947
# 2  -0.791696  -0.124248
# 3  -1.138968   0.109063
# ...

# %%
import matplotlib.pyplot as plt

for i in data.columns:
    plt.figure(1)
    plt.title(i)
    plt.xlabel('TIME')
    plt.ylabel('VALUE')
    plt.grid(axis='y')
    plt.xticks(list(range(0,len(data))))
    plt.plot(list(range(0,len(data))), (data[i]))
    plt.legend(['주택용'])
    plt.show()

# %% [markdown]
# # 최적 시차 선정

# %%
lag_order = select_order(data=data, maxlags=4, deterministic="co", seasons=4)
lag_order.summary()
# Out:
# <class 'statsmodels.iolib.table.SimpleTable'>

# %%
rank_test = select_coint_rank(data, 0, 4, method="trace",
                              signif=0.05)
rank_test.rank
# Out:
# 8

# %%
rank_test.summary()
# Out:
# <class 'statsmodels.iolib.table.SimpleTable'>

# %% [markdown]
# # 공적분 검정

# %%
data.columns[:]
# Out:
# Index(['2차 차분_주택용', '2차 차분_일반용', '2차 차분_교육용', '1차 차분_산업용', '1차 차분_농사용',
#        '2차 차분_가로등', '2차 차분_심야', '2차 차분_GDP'],
#       dtype='object')

# %%
for i in data.columns[:-1]:
    score, pvalue, _ = coint(data['2차 차분_GDP'],data[i],maxlag=7)
    print('****** GDP - '+ str(i)+'공적분 검정 *******')
    print('Cointegration test p-value: ' + str(round(pvalue,4)))
    print("")
# Out:
# ****** GDP - 2차 차분_주택용공적분 검정 *******
# Cointegration test p-value: 0.0
#
# ****** GDP - 2차 차분_일반용공적분 검정 *******
# Cointegration test p-value: 0.0
#
# ****** GDP - 2차 차분_교육용공적분 검정 *******
# Cointegration test p-value: 0.0075
#
# ****** GDP - 1차 차분_산업용공적분 검정 *******
# Cointegration test p-value: 0.0466
#
# ****** GDP - 1차 차분_농사용공적분 검정 *******
# Cointegration test p-value: 0.0
#
# ****** GDP - 2차 차분_가로등공적분 검정 *******
# Cointegration test p-value: 0.0
#
# ****** GDP - 2차 차분_심야공적분 검정 *******
# Cointegration test p-value: 0.0

# %% [markdown]
# # VECM 추정

# %%
data
# Out:
#     2차 차분_주택용  2차 차분_일반용  2차 차분_교육용  1차 차분_산업용  1차 차분_농사용  2차 차분_가로등  \
# 0    0.141395   0.231286  -0.077259  -0.001156   0.113362   0.159865
# 1   -0.075722  -0.346275   0.098201   0.031125   0.131109   0.216564
# 2    0.070878   0.209245  -0.139297  -0.009854  -0.091526  -0.201993
# 3   -0.151208  -0.135949   0.060130   0.018920  -0.167365  -0.225882
# 4    0.130036   0.244559  -0.046480  -0.019996   0.080476   0.217007
# ..        ...        ...        ...        ...        ...        ...
# 75  -0.209337  -0.335297  -0.627796  -0.001316  -0.291297  -0.138491
# 76   0.381442   0.403318   0.497532   0.034230   0.216517   0.125131
# 77  -0.492809  -0.346513  -0.028845  -0.012297  -0.025998   0.174765
# 78   0.310890   0.253302   0.127284   0.021546   0.176975  -0.148353
# 79  -0.207579  -0.298181  -0.576559  -0.023959  -0.285191  -0.150611
#
#     2차 차분_심야  2차 차분_GDP
# 0  -0.292323  -0.053086
# 1   2.193759   0.048947
# 2  -0.791696  -0.124248
# 3  -1.138968   0.109063
# ...

# %%
# 10개 이전만 훈련

model = VECM(data[:len(data)-10], deterministic="co",
             k_ar_diff=4,
             coint_rank=8)

# %%
vecm_res = model.fit()
vecm_res.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
# Det. terms outside the coint. relation & lagged endog. parameters for equation 2차 차분_주택용
# ...
#                    coef    std err          z      P>|z|      [0.025      0.975]
# --------------------------------------------------------------------------------
# const            0.0051      0.006      0.877      0.381      -0.006       0.016
# L1.2차 차분_주택용     5.6391      0.970      5.811      0.000       3.737       7.541
# L1.2차 차분_일반용    -2.9730      1.373     -2.165      0.030      -5.665      -0.281
# L1.2차 차분_교육용    -1.5996      0.808     -1.979      0.048      -3.184      -0.015
# L1.1차 차분_산업용    -0.8583      0.350     -2.455      0.014      -1.543      -0.173
# L1.1차 차분_농사용    -0.3234      0.261     -1.241      0.215      -0.834       0.187
# L1.2차 차분_가로등     0.0702      0.948      0.074      0.941      -1.788       1.928
# L1.2차 차분_심야      0.9738      0.419      2.324      0.020       0.152       1.795
# ...

# %%
predict = vecm_res.predict(steps=10)

# %%
pred_df = data[:len(data)-10]
tmp_df = pd.DataFrame(predict)
tmp_df.columns = data.columns
pred_df = pd.concat([pred_df,tmp_df],axis=0)

# %%
plt.figure(figsize=(10,5))
plt.title('GDP predict')
plt.xlabel('time')
plt.ylabel('GDP')
plt.grid(axis='y')
plt.xticks(list(range(0,len(data))))
plt.plot(list(range(0,len(data))), data['2차 차분_GDP'])
plt.plot(list(range(0,len(data))), pred_df['2차 차분_GDP'])
plt.legend(['2차 차분 GDP', '2차 차분 GDP 예측값'])
plt.show()
